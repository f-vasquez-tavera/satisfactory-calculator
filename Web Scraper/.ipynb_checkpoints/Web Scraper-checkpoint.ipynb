# %%
### TO DO
## ITEMS:
# Ores (DONE)
# Components (DONE)
#- Grab the standard recipe for each component
# Equipment
## BUILDINGS (DONE)
## RECIPES
#- Obtain alternate recipes from Hard Drive page

# %%
import requests
import bs4
base_url = 'https://satisfactory.fandom.com/wiki/{}'
import numpy as np
import pandas as pd
import re

# %%
ComponentTable = pd.read_pickle('../Data/Components')
OreTable = pd.read_pickle('../Data/ores')
building_table = pd.read_pickle('../Data/buildings')
alternate_table = pd.read_pickle('../Data/alt_recipes')

# %%
### This is the code to grab the lists of items

##Gets the list of ore names
def get_ore_names():
    ores = requests.get('https://satisfactory.fandom.com/wiki/Category:Ores')
    soup = bs4.BeautifulSoup(ores.text,"lxml")
    oretext = soup.select('div.mw-category-group')
    ore_list = set()

    txt = oretext[0]

    for item in oretext:
        new = item.find_all('a')
        for sub in new:
            ore_list.add(sub['title'])

    return list(ore_list)

# %%
def get_comp_dict():
    '''Ouputs a list of components and their corresponding data in DataFrame format'''
    #Gets the list of components and conveniently the tier data as part of a filter 
    # because I'm bad at scraping.
    #Ouputs a dictionary of Component Name:Tier
    #Start by getting the ores witht their tiers.
    item_page = requests.get('https://satisfactory.fandom.com/wiki/Satisfactory_Wiki')
    soup = bs4.BeautifulSoup(item_page.text,"lxml")
    componentvomit = soup.select('.navbox')[14]
    example = componentvomit.find_all('a', title=True)
    comp_list = {}
    comp_dict = {}
    cat = ""
    for item in example:
        if 'Tier' in item['title'] or 'MAM' in item['title']:
            cat = item['title']
            cat.replace('Tier ','')
        else:
            comp_list[item['title']] = cat
    comp_list['Biomass'] = 'Tier 0'
    comp_list.pop('Research',None)
    
    comp_keys = [*comp_list]
    
    ##Extract relevant values from item pages
    tier_list = []
    std_recipe_list = []
    output_rate_list = []
    alt_recipe_list = []
    sink_value_list = []
    stack_size_list = []
    
    for key in comp_keys:
        
        page = requests.get(base_url.format(key))
        soup = bs4.BeautifulSoup(page.text,"lxml")
        
        # Research Tier
        # MAM recipes don't have tiers
        if comp_list[key] == "MAM":
            infobox = soup.select('.portable-infobox')
            a_s = infobox[0].find_all('a')[1]
            try:
                tier = a_s['title']
                tier = tier.replace("Tier ", "")
                #maybe remove this replace function and add it in when the list is called.
            except:
                tier = "Not Implemented"
        else:    
            tier = comp_list[key]
        
        # Stack size and sink value
        stack_size = ''
        sink_value = ''
        
        try:
            aside = soup.select('aside')[0]
            for line in aside.find_all('div'):
                try:
                    if line.find('a')['title'] == 'Stack':
                        stack_size = line.find('div').text
                    elif line.find('a')['title'] == 'AWESOME Sink':
                        sink_value = line.find('div').text
                except:
                    pass

        except Exception as e:
            print(e)
            print(key)
        
        # Default Recipe code still doesn't work.
#         recipe = 
#         output =
        
#         entry = soup.select('.wikitable')[0].find_all('td')
#         product = entry[3].find_all('span')[1].text
#         ingredients = entry[1].text
        
        # Alternate Recipe Names
        try:
            craft = soup.select('.wikitable')[0]
            rows = craft.find_all('tr')
        except:
            craft = []

        alt_recipes = []
        for ind in range(8):
            try:
                if "Alternate" in rows[ind+2].find('td').text:
                    alt = rows[ind+2].find('td').text
                    alt.replace("Alternate","")
                    altalt = re.sub(r'Alternate','',alt)
                    altalt = re.sub(r": ", "", altalt)
                    alt_recipes.append(altalt)
            except:
                pass
        
        #Append values to lists
        tier_list.append(tier)
        sink_value_list.append(sink_value)
        stack_size_list.append(stack_size)
        alt_recipe_list.append(alt_recipes)
    
    comp_dict["Tier"] = tier_list
    comp_dict["Alternate Recipes"] = recipe_list_list
    comp_dict["Stack Size"] = stack_size_list
    comp_dict["Sink Value"] = sink_value_list
    #Last step - return the names of items and comp_dict in the same order
    return comp_keys, comp_dict

# %%
comp_keys, comp_dict = get_comp_dict()
ComponentTable = pd.DataFrame(comp_dict, index=comp_keys)
ComponentTable.head()
# Out:
#                 Tier                                 Alternate Recipes  \
# Biomass       Tier 0                                                []
# Cable         Tier 0  [Coated Cable, Insulated Cable, Quickwire Cable]
# Concrete      Tier 0    [Rubber Concrete, Wet Concrete, Fine Concrete]
# Copper Ingot  Tier 0           [Copper Alloy Ingot, Pure Copper Ingot]
# Iron Ingot    Tier 0               [Pure Iron Ingot, Iron Alloy Ingot]
#
#              Stack Size Sink Value
# Biomass             200         12
# Cable               200         24
# Concrete            500         12
# Copper Ingot        100          6
# Iron Ingot          100          2

# %%
ComponentTable.to_pickle('../Data/Components')

# %%
#Grab important values for each ore
#Tier, Sink Value, Mining Speed, No. of nodes 
def get_ore_dict(oredered_list=get_ore_names()):
    ore_dict = {}
    unlock_list = []
    stack_size_list= []
    sink_value_list = []
    mining_list = []
    node_dict = {'Impure':0, 'Normal':0, 'Pure':0}
    impure_list = []
    normal_list = []
    pure_list = []
    
    for ore in oredered_list:
        
        name = requests.get(base_url.format(ore))
        soup = bs4.BeautifulSoup(name.text,"lxml")

        #Tier Acquired, Stack Size, Sink Value
        aside = soup.select('aside')[0]
        index = 0
        for line in aside.find_all('a'):
            if line['title'] == 'Stack':
                stack_index = index*2
                stack_size = aside.find_all('div')[stack_index].contents[3].text
            elif line['title'] == 'AWESOME Sink':
                sink_index = index*2
                sink_value = aside.find_all('div')[sink_index].contents[3].text
            index += 1
        unlock = aside.find_all('a')[1]['title']
        
        # SAM Ore page format was significantly different so I gave up trying to automate this
        # WHEN UPDATING CHECK THIS MANUALLY
        if ore == "SAM Ore":
            stack_size = 50
            sink_value = 'N/A'

        #Mining Speed - Mk.1 - Impure
        for item in soup.select('tbody'):
            if item.find('a')['title'] == 'Miner Mk.1':
                mining = item
                break

        speed = mining.find_all('tr')[1].contents[1].contents[0].text

        #No. of nodes - populates node_dict with node types and values
        for line in soup.select('tbody'):
            if "Numberof nodes" in line.text:
                nodes = line
        node_names = ["Impure","Normal","Pure"]
        follow = False
        key = ''
        for line in nodes.find_all('td'):
            if follow:
                node_dict[key] = line.text
            if any(node in line.text for node in node_names):
                key = line.text
                follow = True
            else:
                follow = False

        #Append new values to list for dictionary
        unlock_list.append(unlock)
        stack_size_list.append(stack_size)
        sink_value_list.append(sink_value)
        mining_list.append(speed)
        impure_list.append(node_dict['Impure'])
        normal_list.append(node_dict['Normal'])
        pure_list.append(node_dict['Pure'])
        
    ore_dict["Unlocks at"] = unlock_list
    ore_dict["Stack Size"] = stack_size_list
    ore_dict["Sink Value"] = sink_value_list
    ore_dict["Mining Speed"] = mining_list
    ore_dict["Impure Nodes"] = impure_list
    ore_dict["Normal Nodes"] = normal_list
    ore_dict["Pure Nodes"] = pure_list
        
    return ore_dict
    
    #Final section will take all previous results and append them all to a DataFrame

# %%
oredered_list = get_ore_names()
ore_dict = get_ore_dict(oredered_list=oredered_list)
OreTable = pd.DataFrame(ore_dict, index=oredered_list)
OreTable.head()
# Out:
#                  Unlocks at Stack Size Sink Value Mining Speed Impure Nodes  \
# Sulfur      Sulfur Research        100         11           30            1
# Copper Ore           Tier 0        100          3           30            9
# Bauxite              Tier 7        100          8           30            5
# Limestone            Tier 0        100          2           30           12
# Coal                 Tier 3        100          3           30            6
#
#            Normal Nodes Pure Nodes
# Sulfur                7          3
# Copper Ore           28         12
# Bauxite               6          6
# Limestone            47         27
# Coal                 29         14

# %%
OreTable.to_pickle('../Data/ores')

# %%
def get_building_values():
### This is the code to grab the list of buildings
    builres = requests.get("https://satisfactory.fandom.com/wiki/Buildings")
    soup = bs4.BeautifulSoup(builres.text,"lxml")
    #This is the relevant information for buildings: name, ingredients.
    btable = soup.select('.wikitable')[0]

    try1 = btable.select('tr')
    building_dict = {}

    #Grabs all 355 building names
    for item in try1:

        tds = item.select('td')

        try:
            bs = tds[1].select('b')
            a_s = tds[1].select('a')

            #Grabs building names
            Building = tds[0].text


            #Grabs ingredient quantities
            blist = []
            for item in bs:
                blist.append(item.text)
            blist

            #Grabs ingredient names
            adict = {}
            for item in a_s:
                adict[item['title']]=""
            #Combines all into a dict of buildings: dict of ingredients to quantities
            
            building_dict[Building] = {'Recipe': dict(zip(adict, blist))}
        except Exception as e:
            pass

    # Grab the dimensions of all buildings
    i = 0
    for item in soup.select('tbody')[2].select('td'):
        try:
            if i == 0 or i%5 == 0:
                key = item.find('a')['title']
                try:
                    superkey = building_dict[key]
                except:
                    superkey = building_dict[key+'FICS⁕MAS']
            elif i%5 == 1:
                superkey['Width'] = item.text
            elif i%5 == 2:
                superkey['Length'] = item.text
            elif i%5 == 3:
                superkey['Height'] = item.text
            elif i%5 == 4:
                superkey['Area'] = item.text
            i += 1
        except:
            pass
    return building_dict

# %%
building_dict = get_building_values()
building_table = pd.DataFrame.from_dict(building_dict, orient='index')

# %%
building_table.to_pickle('../Data/buildings')

# %%
'''This is the code to grab the list of recipes
Because of the way recipes are stored in the wiki, 
you have to get the basic recipe from each item page
Then you can get the list of alternate recipes from the hard drive page

Relevant data to get for each recipe:
Recipe Name,Product, Building, Ingredients, Rate/min, Prerequisites'''

# %%
alt_recipes_list = ComponentTable["Alternate Recipes"].tolist()
alt_recipes_set = set()
for item in alt_recipes_list:
    for sub in item:
        alt_recipes_set.add(sub)
alt_recipes_list = list(alt_recipes_set)
alt_recipes_list.sort()

# %%
alt_recipes_list
# Out:
# ['Adhered Iron Plate',
#  'Alclad Casing',
#  'Automated Speed Wiring',
#  'Bolted Frame',
#  'Bolted Iron Plate',
#  'Cast Screw',
#  'Caterium Circuit Board',
#  'Caterium Computer',
#  'Caterium Wire',
#  'Cheap Silica',
#  'Classic Battery',
#  'Coated Cable',
#  'Coated Iron Plate',
#  'Coke Steel Ingot',
#  'Compacted Steel Ingot',
#  'Cooling Device',
#  'Copper Alloy Ingot',
#  'Copper Rotor',
#  'Crystal Computer',
#  'Diluted Fuel',
#  'Diluted Packaged Fuel',
#  'Electric Motor',
#  'Electrode - Aluminum Scrap',
#  'Electrode Circuit Board',
#  'Electromagnetic Connection Rod',
#  'Encased Industrial Pipe',
#  'Fertile Uranium',
#  'Fine Black Powder',
#  'Fine Concrete',
#  'Flexible Framework',
#  'Fused Quickwire',
#  'Fused Wire',
#  'Heat Exchanger',
#  'Heat-Fused Frame',
#  'Heavy Encased Frame',
#  'Heavy Flexible Frame',
#  'Heavy Oil Residue',
#  'Infused Uranium Cell',
#  'Instant Plutonium Cell',
#  'Instant Scrap',
#  'Insulated Cable',
#  'Insulated Crystal Oscillator',
#  'Iron Alloy Ingot',
#  'Iron Wire',
#  'OC Supercomputer',
#  'Plastic Smart Plating',
#  'Plutonium Fuel Unit',
#  'Polyester Fabric',
#  'Polymer Resin',
#  'Pure Aluminum Ingot',
#  'Pure Caterium Ingot',
#  'Pure Copper Ingot',
#  'Pure Iron Ingot',
#  'Pure Quartz Crystal',
#  'Quickwire Cable',
#  'Quickwire Stator',
#  'Radio Connection Unit',
#  'Radio Control System',
#  'Recycled Plastic',
#  'Recycled Rubber',
#  'Rigour Motor',
#  'Rubber Concrete',
#  'Silicon Circuit Board',
#  'Silicon High-Speed Connector',
#  'Sloppy Alumina',
#  'Solid Steel Ingot',
#  'Steamed Copper Sheet',
#  'Steel Coated Plate',
#  'Steel Rod',
#  'Steel Rotor',
#  'Steel Screw',
#  'Steeled Frame',
#  'Stitched Iron Plate',
#  'Super-State Computer',
#  'Turbo Blend Fuel',
#  'Turbo Electric Motor',
#  'Turbo Heavy Fuel',
#  'Turbo Pressure Motor',
#  'Turbofuel',
#  'Uranium Fuel Unit',
#  'Wet Concrete']

# %%
alternates = requests.get('https://satisfactory.fandom.com/wiki/Hard_Drive')
soup = bs4.BeautifulSoup(alternates.text,'lxml')
test = soup.select('.wikitable')[1]

# %%
test = soup.select('.wikitable')[1]
another = test.find_all('tr')[8]
idict = {}
key = ""
#for item in another:
onemore = another.find_all('a')
key = onemore[0].text
another.find_all('td')
#code is smth like for each item in test.find_all('tr')
#td[0] is the name
#td[1] is the product
#td[2] contains ingredients
#td[3] is the rate/min
#tr[6] is the prerequisites
# Out:
# [<td style="text-align:left;position:relative; overflow:hidden;padding-top:2.2em;padding-bottom:2.2em;"><a href="/wiki/Wire#Alternate_recipes_analysis" title="Wire">Caterium Wire</a></td>,
#  <td><a class="image" href="https://static.wikia.nocookie.net/satisfactory_gamepedia_en/images/7/77/Wire.png/revision/latest?cb=20200311155702"><img alt="Wire.png" class="lazyload" data-file-height="256" data-file-width="256" data-image-key="Wire.png" data-image-name="Wire.png" data-src="https://static.wikia.nocookie.net/satisfactory_gamepedia_en/images/7/77/Wire.png/revision/latest/scale-to-width-down/30?cb=20200311155702" decoding="async" height="30" src="...%3D%3D" width="30"/></a> <a href="/wiki/Wire" title="Wire">Wire</a></td>,
#  <td style="vertical-align:right;"><a class="image" href="https://static.wikia.nocookie.net/satisfactory_gamepedia_en/images/f/f4/Caterium_Ingot.png/revision/latest?cb=20200311142310"><img alt="Caterium Ingot.png" class="lazyload" data-file-height="256" data-file-width="256" data-image-key="Caterium_Ingot.png" data-image-name="Caterium Ingot.png" data-src="https://static.wikia.nocookie.net/satisfactory_gamepedia_en/images/f/f4/Caterium_Ingot.png/revision/latest/scale-to-width-down/30?cb=20200311142310" decoding="async" height="30" src="...%3D%3D" width="30"/></a> <a href="/wiki/Caterium_Ingot" title="Caterium Ingot">Caterium Ingot</a> <span style="float:right;padding-right:0.5em;padding-top:0.4em;">15.0</span></td>,
#  <td style="text-align:right;">120.0</td>,
#  <td style="text-align:right;">30.0</td>,
#  <td style="vertical-align: right;"><span style=""><a class="image" href="https://static.wikia.nocookie.net/satisfactory_gamepedia_en/images/0/00/Copper_Ingot.png/revision/latest?cb=20200320134532"><img alt="Copper Ingot.png" class="lazyload" data-file-height="256" data-file-width="256" data-image-key="Copper_Ingot.png" data-image-name="Copper Ingot.png" data-src="https://static.wikia.nocookie.net/satisfactory_gamepedia_en/images/0/00/Copper_Ingot.png/revision/latest/scale-to-width-down/30?cb=20200320134532" decoding="async" height="30" src="...%3D%3D" width="30"/></a> <a href="/wiki/Copper_Ingot" title="Copper Ingot">Copper Ingot</a></span><span style="float:right;padding-top:0.25em;">15.0</span></td>,
#  <td><a class="mw-redirect" href="/wiki/Caterium_Research" title="Caterium Research">Caterium Research</a> - Caterium</td>]

# %%
test.find_all('tr')[1].find_all('td')[0].text
# Out:
# 'Copper Alloy Ingot'

# %%
def get_alternate_recipes():
    alternates = requests.get('https://satisfactory.fandom.com/wiki/Hard_Drive')
    soup = bs4.BeautifulSoup(alternates.text,'lxml')
    table = soup.select('.wikitable')[1]
    alternate_dict = {}
    for tr in table.find_all('tr'):
        try:
            entry = tr.find_all('td')
            name = entry[0].text
            product = entry[1].text
            ingredients = entry[2].text
            rate = entry[3].text
            prereqs = entry[6].text
            alternate_dict[name] = {"Product":product, 
                                    "Ingredients/min":ingredients, 
                                    "Rate/min": rate, 
                                    "Prerequisites": prereqs}
        except:
            continue
    return alternate_dict

# %%
alternate_dict = get_alternate_recipes()
alternate_table = pd.DataFrame.from_dict(alternate_dict, orient='index')

# %%
alternate_table.to_pickle('../Data/alt_recipes')

# %%
page = requests.get(base_url.format('Computer'))
soup = bs4.BeautifulSoup(page.text,"lxml")

# %%
soup.select('.wikitable')[0].find_all('tr')[-1].find_all('td')[0].text
# Out:
# 'Pure Copper IngotAlternate'

# %%
entry = soup.select('.wikitable')[0].find_all('td')
name = entry[0].text
product = entry[3].text
ingredients = entry[1].text
prereqs = entry[4].text

# %%
for e in entry:
    print(e.text)
# Out:
# Computer
# 10 × Circuit Board25 / min
# 9 × Cable22.5 / min
# Manufacturer24 sec × 18
# 1 × Computer2.5 / min1320 MJ/item
# Tier 5 - Industrial Manufacturing
# 18 × Plastic45 / min
# 52 × Screw130 / min
# Crystal ComputerAlternate
# 8 × Circuit Board7.5 / min
# 3 × Crystal Oscillator2.8125 / min
# Assembler64 sec
# 3 × Computer2.8125 / min320 MJ/item
# Tier 5 - Industrial ManufacturingQuartz Research - Quartz Crystal
# Caterium ComputerAlternate
# 7 × Circuit Board26.25 / min
# 28 × Quickwire105 / min
# Manufacturer16 sec
# 1 × Computer3.75 / min880 MJ/item
# Tier 5 - Industrial ManufacturingCaterium Research - Caterium Ingots
# 12 × Rubber45 / min

# %%
'''Building Rules for Recipes Pseudocode
If name in FICSMAS_list: Use dict.
    {Smelter: ['Blue FICSMAS Ornament', 'Red FICSMAS Ornament'],
    Constructor: ['Actual Snow', 'Candy Cane', 'FICSMAS Bow', 'FICSMAS Tree Branch', 'Snow'],
    Assembler: ['Fancy Fireworks', 'FICSMAS Decoration', 'FICSMAS Ornament Bundle', 
                'FICSMAS Wonder Star', ' Sparkly Fireworks', 'Sweet Fireworks']}
Elif ingredient_types (solid AND fluid AND no_ingredients >=2) OR (fluid AND no_ingredients == 2): Blender
Elif (solid AND fluid AND no_ingredients <= 2) OR (fluid AND no_ingredients == 1): Refinery
elif solid AND no_ingredients =1 1:
    if "ore" OR "scrap", in ingredients.text: Smelter
    else: Constructor
elif solid AND no_ingredients 1= 2: Assembler
else: Manufacturer

'''

# %%
'''TO DOS
Energy consumption per item for each recipe

For the standard recipe, find a way to index the ingredients properly.

'''
